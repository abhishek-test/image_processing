# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
image = cv2.imread('C:\\Users\\abhishek.sri\\Downloads\\barcodes\\blurred.png', 0)



image_sharp = cv2.filter2D(image, -1, kernel)

cv2.imwrite("C:\\Users\\abhishek.sri\\Downloads\\barcodes\\sharpened.png", image_sharp)

plt.figure(figsize=[12,5])

plt.subplot(121)
plt.imshow(image, cmap='gray')
plt.title('Original Image')

plt.subplot(122)
plt.imshow(image_sharp, cmap='gray')
plt.title('Sharpened image')
# Out:
# Text(0.5, 1.0, 'Sharpened image')
